# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from dateutil.relativedelta import relativedelta
import json

# local imports
from find_sites import findSites

import sys
sys.path.append('/Users/olivia/main/research/atmospheric_chem_ML/chem150')

# I am currently unsure if it will be able to find this environment file but ahhh
from data_fetcher import DataFetcher

datafetcher = DataFetcher()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
findsites = findSites()

# %%
df = findsites.find_sites('Ozone', '06', 1980, 2020)
df
# Out:
#    site_number  open_date close_date  Ozone
# 0         1006       1979       None   True
# 1         0002       1978       None   True
# 2         0001       1975       None   True
# 3         2001       1977       None   True
# 4         0004       1976       None   True
# 5         1103       1979       None   True
# 6         5001       1975       None   True
# 7         1001       1976       None   True
# 8         1201       1978       None   True
# 9         1002       1976       2021   True
# 10        1004       1973       None   True
# 11        0005       1979       None   True
# 12        6001       1979       None   True
# 13        1701       1978       None   True
# 14        8001       1975       None   True
# 15        2002       1979       2021   True
# 16        3001       1979       None   True

# %%
df = findsites.best_sites_state('06', 1980)
df
# Out:
# [   site_number  open_date close_date  Ozone
#  0         1006       1979       None   True
#  1         0002       1978       None   True
#  2         0001       1975       None   True
#  3         2001       1977       None   True
#  4         0004       1976       None   True
#  5         1103       1979       None   True
#  6         5001       1975       None   True
#  7         1001       1976       None   True
#  8         1201       1978       None   True
#  9         1004       1973       None   True
#  10        0005       1979       None   True
#  11        6001       1979       None   True
#  12        1701       1978       None   True
#  13        8001       1975       None   True
#  14        3001       1979       None   True]

# %% [markdown]
# Ok so now let's try doing two different types, and we'll see if the true/false thing works!

# %%
# df2 = findsites.best_sites_state('06', 2000, other_params=["Wind Direction - Resultant"])
df2 = findsites.best_sites_state('06', 2000)
df2
# Out:
# ['PM2.5 - Local Conditions', 'Wind Direction - Resultant']
#              Wind Direction - Resultant
# site_number
# False                                 0
# 0001                                  1
# 0002                                  1
# 0003                                  1
# 0004                                  1
# 0005                                  1
# 0006                                  1
# 0007                                  1
# 0008                                  1
# 0010                                  1
# 0011                                  1
# 0012                                  1
# 0014                                  1
# 0016                                  1
# 0101                                  1
# 0113                                  1
# 0242                                  1
# 1002                                  1
# 1004                                  1
# 1006                                  1
# 1008                                  1
# ...

# %%
other = df2.fillna(value=False)
aggregation_functions = {'site_name': 'sum','Ozone': 'sum', 'PM2.5 - Local Conditons': 'sum'}
df_new = other.groupby(other['site_number']).sum()
df_new
# Out:
#              Ozone  PM2.5 - Local Conditions
# site_number
# 0001             1                         1
# 0002             1                         1
# 0003             1                         0
# 0004             1                         1
# 0005             1                         1
# 0006             1                         1
# 0007             1                         0
# 0008             1                         0
# 0009             1                         0
# 0010             1                         0
# 0011             1                         0
# 0012             1                         0
# 0014             1                         1
# 0016             1                         0
# 0020             1                         0
# 0101             1                         0
# 0113             1                         0
# 0232             1                         0
# 0242             1                         0
# ...
