# %% [markdown]
# # Walkthrough of using the Site Finder!

# %% [markdown]
# ## Imports!

# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from dateutil.relativedelta import relativedelta
import json

# local imports
from find_sites import findSites
findsites = findSites()

import sys
sys.path.append('/Users/olivia/main/research/atmospheric_chem_ML/chem150')
from data_fetcher import DataFetcher
datafetcher = DataFetcher()

# %% [markdown]
# ## Walkthrough

# %% [markdown]
# Here is an example of a pull of the best sites for a state:

# %%
    # def best_sites_state(self, state, byear, eyear=None, other_params=[]):

df = findsites.best_sites_state('06', 2000, other_params=['Wind Direction - Resultant'])
df
# Out:
#             county_code  Ozone  PM2.5 - Local Conditions  \
# site_number
# 0001                009      1                         1
# 0002                067      1                         1
# 0004                039      1                         1
# 0005                057      1                         1
# 0006                067      1                         1
# 0014                029      1                         1
# 1006                073      1                         1
# 1103                037      1                         1
# 1201                037      1                         1
# 2002                071      1                         1
# 2005                037      1                         1
# 4002                079      1                         1
# 5001                019      1                         1
# 8001                065      1                         1
# 9004                071      1                         1
# 1001                085      1                         1
# 1003                053      1                         1
# 0003                069      1                         0
# 0007                001      1                         0
# 0008                029      1                         0
# 0010                017      1                         0
# 0011                067      1                         0
# 0012                065      1                         0
# 0016                037      1                         0
# 0101                027      1                         0
# 0113                037      1                         0
# 0242                019      1                         0
# 1002                011      1                         0
# 1004                031      1                         0
# 1008                073      1                         0
# 1013                083      1                         0
# 1014                083      1                         0
# 1021                083      1                         0
# 1025                083      1                         0
# 1701                037      1                         0
# 2004                083      1                         0
# 2011                083      1                         0
# 3001                079      1                         0
# 3003                089      1                         0
# 4001                019      1                         0
# 4003                071      1                         0
# 5003                067      1                         0
# 6001                029      1                         0
# 9001                065      1                         0
# 9002                071      1                         0
# 0009                107      1                         0
# 0020                017      1                         0
# 0232                029      1                         0
# 1234                071      1                         0
# 2001                001      1                         0
# 2006                085      1                         0
# 4004                025      1                         0
# 2022                059      0                         1
# 1020                083      0                         0
# 1022                083      0                         0
#
#              Wind Direction - Resultant
# site_number
# 0001                                  1
# 0002                                  1
# 0004                                  1
# 0005                                  1
# 0006                                  1
# 0014                                  1
# 1006                                  1
# 1103                                  1
# 1201                                  1
# 2002                                  1
# 2005                                  1
# 4002                                  1
# 5001                                  1
# 8001                                  1
# 9004                                  1
# 1001                                  0
# 1003                                  0
# 0003                                  1
# 0007                                  1
# 0008                                  1
# 0010                                  1
# 0011                                  1
# 0012                                  1
# 0016                                  1
# 0101                                  1
# 0113                                  1
# 0242                                  1
# 1002                                  1
# 1004                                  1
# 1008                                  1
# 1013                                  1
# 1014                                  1
# 1021                                  1
# 1025                                  1
# 1701                                  1
# 2004                                  1
# 2011                                  1
# 3001                                  1
# 3003                                  1
# 4001                                  1
# 4003                                  1
# 5003                                  1
# 6001                                  1
# 9001                                  1
# 9002                                  1
# 0009                                  0
# 0020                                  0
# 0232                                  0
# 1234                                  0
# 2001                                  0
# 2006                                  0
# 4004                                  0
# 2022                                  1
# 1020                                  1
# 1022                                  1

# %% [markdown]
# Ok now as a test, we're going to pull from one of the sites that works!! 0001 works!

# %%
# THIS ONE CAUSED AN ERROR FOR THE CHECKER!!!
datafetcher.create_dataset(20000101, 20050101, site='0001', county='073', state='06')
# Out:
# 2000
# 2005
# {'Header': [{'status': 'Failed', 'request_time': '2022-06-10T12:45:53.106-04:00', 'url': 'https://aqs.epa.gov/data/api/annualData/bySite?email=orussell%40g.hmc.edu&key=silverwren95&param=88101&bdate=20000101&edate=20050101&state=06&county=073&site=0001', 'error': ['bdate: 20000101, edate: 20050101, only 1 year of data is permitted.']}]}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/8_/jl8082c91j51t0f1_pj4h2j80000gn/T/ipykernel_21033/3687255165.py in <module>
#       1 # THIS ONE CAUSED AN ERROR FOR THE CHECKER!!!
# ----> 2 datafetcher.create_dataset(20000101, 20050101, site='0001', county='073', state='06')
#
# ~/main/research/atmospheric_chem_ML/chem150/data_fetcher.py in create_dataset(self, bdate, edate, site, county, state, processed, verbose)
#     260                 # if we want to do an extra check for PM2.5 since it's often not hourly
#     261                 if code == pm25:
# --> 262                     year = self.annual_checker(code, bdate, edate, site, county, state)
#     263                     if year == 0: # so there is no data
#     264                         print(f"No hourly data for {dct[code]} (annual check)")
#
# ~/main/research/atmospheric_chem_ML/chem150/data_fetcher.py in annual_checker(self, code, bdate, edate, site, county, state)
#     336             # calls annual
#     337             annual_df = self.get_data(ANNUAL_DATA_BY_SITE, code, yr_start, yr_end, df = True, nparams={'state':state, 'county':county, 'site':site})
# --> 338             annual_df = annual_df[annual_df['sample_duration'] == '1 HOUR']
#     339             if not annual_df.empty: # if it's not empty
#     340                 return curr_year
#
# TypeError: 'NoneType' object is not subscriptable

# %%
# this is an annual checker problem!

# annual_checker(self, code, bdate, edate, site, county, state):

datafetcher.annual_checker(88101, 20000101, 20050101, site='0001', county='073', state='06')

# %% [markdown]
# So this location doesn't have hourly PM2.5 data, so it's actually not great.
#
# I'm building a second function in the datafetcher though that can tell you the range for when PM2.5 is available!

# %%
# now let's see how our annual function is doing

df = datafetcher.annual_checker(88101, 20180618, 20180618, '4004', '037', '06')
df
# Out:
# There is hourly PM2.5 data starting on this year!
#   state_code county_code site_number parameter_code  poc  latitude  longitude  \
# 0         06         037        4004          88101    3  33.79236 -118.17533
#
#    datum                 parameter sample_duration_code  ...  \
# 0  WGS84  PM2.5 - Local Conditions                    1  ...
#
#   fiftieth_percentile tenth_percentile     local_site_name  \
# 0                11.1              4.6  Long Beach (South)
#
#                              site_address       state       county  \
# 0  1305 E. Pacific Coast Hwy., Long Beach  California  Los Angeles
#
#          city  cbsa_code                                cbsa  \
# 0  Long Beach      31080  Los Angeles-Long Beach-Anaheim, CA
#
#   date_of_last_change
# 0          2022-05-05
#
# [1 rows x 56 columns]
